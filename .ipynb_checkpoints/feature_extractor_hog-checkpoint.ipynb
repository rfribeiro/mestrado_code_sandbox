# %%
# %matplotlib inline

import glob
import pandas as pd
import yaml
import numpy as np
import cv2
import time
from skimage import exposure
from skimage import feature
import matplotlib.pyplot as plt

# %%
prefix = 'C:\\Users\\rafae\\Desktop\\Coleta\\faces\\training_*.csv'

# %%
import yaml
skip_lines = 3
def read_yaml_depth(file):
    file_yaml = file.replace('bmp', 'yaml')
    print(file_yaml)
    with open(file_yaml) as infile:
        for i in range(skip_lines):
            _ = infile.readline()
        data = yaml.load(infile)
    return np.reshape(data['data'], (data['rows'], data['cols']))

# %%
def show_hog_img(img, hog_img):
    for i in range(4):
        hog_img[i] = exposure.rescale_intensity(hog_img[i], out_range=(0, 255))
        hog_img[i] = hog_img[i].astype("uint8")

    img_concat = np.concatenate((img[0], img[1],img[2],img[3]), axis = 1)
    img_hog_concat = np.concatenate((img[0], hog_img[1],hog_img[2],hog_img[3]), axis = 1)
    
    img_total = np.concatenate((img_concat, img_hog_concat), axis = 0)
    
    fig, ax = plt.subplots(nrows=1, ncols=4)
    for i in range(4):
        plt.subplot(1, 4, i+1)
        plt.hist(hog_img[i])
    plt.show()

    cv2.imshow("HOG Image", img_total)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
show_hog_image = False

def calculate_hog(row):
    tic = time.clock()
    
    # improvement agrupar
    #dep = cv2.imread(row['depfile_path'],0)
    dep = read_yaml_depth(row['depfile_path'])
    dep = dep[row['depxs']:row['depxe'],row['depys']:row['depye']]
    dep = (dep - dep.mean()) / dep.std()
    (H_dep, dep_hog) = feature.hog(dep, orientations=9, pixels_per_cell=(8, 8),cells_per_block=(2,2), transform_sqrt=True, visualise=True, block_norm='L2-Hys')
    print(dep.shape, dep_hog.shape, H_dep.shape)
    
    ir1 = cv2.imread(row['ir1file_path'],0)
    ir1 = ir1[row['ir1xs']:row['ir1xe'],row['ir1ys']:row['ir1ye']]
    (H_ir1, ir1_hog) = feature.hog(ir1, orientations=9, pixels_per_cell=(8, 8),cells_per_block=(2, 2), transform_sqrt=True, visualise=True, block_norm='L2-Hys')
    #print(ir1.shape, ir1_hog.shape, H_ir1.shape)
    
    ir2 = cv2.imread(row['ir2file_path'],0)
    ir2 = ir2[row['ir2xs']:row['ir2xe'],row['ir2ys']:row['ir2ye']]
    (H_ir2, ir2_hog) = feature.hog(ir2, orientations=9, pixels_per_cell=(8, 8),cells_per_block=(2, 2), transform_sqrt=True, visualise=True, block_norm='L2-Hys')
    #print(ir2.shape, ir2_hog.shape, H_ir2.shape)
    
    rgb = cv2.imread(row['rgbfile_path'],0)
    rgb = rgb[row['rgbxs']:row['rgbxe'],row['rgbys']:row['rgbye']]
    (H_rgb, rgb_hog) = feature.hog(rgb, orientations=9, pixels_per_cell=(8, 8),cells_per_block=(2, 2), transform_sqrt=True, visualise=True, block_norm='L2-Hys')
    #print(rgb.shape, rgb_hog.shape, H_rgb.shape)
    
    data = [row['class'], row['person']]
    data.extend(H_dep)
    data.extend(H_ir1)
    data.extend(H_ir2)
    data.extend(H_rgb)
    
    data_hog.append(data)
    
    if show_hog_image == True:
        show_hog_img([dep,ir1,ir2,rgb], [dep_hog, ir1_hog, ir2_hog, rgb_hog])
        
    print(ds.shape, len(data_hog), row['depfile_path'], (time.clock() - tic))

# %%
# import the necessary packages
from skimage import feature
import numpy as np
 
class LocalBinaryPatterns:
    def __init__(self, numPoints, radius):
        # store the number of points and radius
        self.numPoints = numPoints
        self.radius = radius
 
    def describe(self, image, eps=1e-7):
        # compute the Local Binary Pattern representation
        # of the image, and then use the LBP representation
        # to build the histogram of patterns
        lbp = feature.local_binary_pattern(image, self.numPoints,
            self.radius, method="uniform")
        (hist, _) = np.histogram(lbp.ravel(),
            bins=np.arange(0, self.numPoints + 3),
            range=(0, self.numPoints + 2))
        # normalize the histogram
        hist = hist.astype("float")
        hist /= (hist.sum() + eps)

        # return the histogram of Local Binary Patterns
        return (hist, lbp)

# %%
show_lbp_image = False

def calculate_lbp(row):
    tic = time.clock()
    desc = LocalBinaryPatterns(24, 3)
    
    # improvement agrupar
    depr = read_yaml_depth(row['depfile_path'])
    depr = depr[row['depxs']:row['depxe'],row['depys']:row['depye']]
    depr = (depr - depr.mean()) / depr.std()
    #(H_dep, dep_hog) = feature.hog(dep, orientations=9, pixels_per_cell=(8, 8),cells_per_block=(2,2), transform_sqrt=True, visualise=True, block_norm='L2-Hys')
    (H_depr, depr_hog) = desc.describe(depr)
    print(H_depr.shape)
    #dep = (dep - dep.mean()) / dep.std()
    #dep = cv2.imread(row['depfile_path'],0)    
    #dep = dep[row['depxs']:row['depxe'],row['depys']:row['depye']]
    
    #(H_dep, dep_hog) = feature.hog(dep, orientations=9, pixels_per_cell=(8, 8),cells_per_block=(2,2), transform_sqrt=True, visualise=True, block_norm='L2-Hys')
    #(H_dep, dep_hog) = desc.describe(dep)
    #print(H_dep.shape)
    
    ir1 = cv2.imread(row['ir1file_path'],0)
    ir1 = ir1[row['ir1xs']:row['ir1xe'],row['ir1ys']:row['ir1ye']]
    #(H_ir1, ir1_hog) = feature.hog(ir1, orientations=9, pixels_per_cell=(8, 8),cells_per_block=(2, 2), transform_sqrt=True, visualise=True, block_norm='L2-Hys')
    (H_ir1, ir1_hog) = desc.describe(ir1)
    print(H_ir1.shape)
    #print(ir1.shape, ir1_hog.shape, H_ir1.shape)
    
    ir2 = cv2.imread(row['ir2file_path'],0)
    ir2 = ir2[row['ir2xs']:row['ir2xe'],row['ir2ys']:row['ir2ye']]
    #(H_ir2, ir2_hog) = feature.hog(ir2, orientations=9, pixels_per_cell=(8, 8),cells_per_block=(2, 2), transform_sqrt=True, visualise=True, block_norm='L2-Hys')
    (H_ir2, ir2_hog) = desc.describe(ir2)
    print(H_ir2.shape)
    #print(ir2.shape, ir2_hog.shape, H_ir2.shape)
    
    rgb = cv2.imread(row['rgbfile_path'],0)
    rgb = rgb[row['rgbxs']:row['rgbxe'],row['rgbys']:row['rgbye']]
    #(H_rgb, rgb_hog) = feature.hog(rgb, orientations=9, pixels_per_cell=(8, 8),cells_per_block=(2, 2), transform_sqrt=True, visualise=True, block_norm='L2-Hys')
    (H_rgb, rgb_hog) = desc.describe(rgb)
    print(H_rgb.shape)
    #print(rgb.shape, rgb_hog.shape, H_rgb.shape)
    
    data = [row['class'], row['person']]
    data.extend(H_depr)
    #data.extend(H_dep)
    data.extend(H_ir1)
    data.extend(H_ir2)
    data.extend(H_rgb)
    
    data_hog.append(data)
    
    if show_lbp_image == True:
        show_hog_img([dep,ir1,ir2,rgb], [dep_hog, ir1_hog, ir2_hog, rgb_hog])
        
    print(ds.shape, len(data_hog), row['depfile_path'], (time.clock() - tic))

# %%
files_list = glob.glob(prefix)
print(len(files_list))
# Out:
# 518

# %%
feature_desc = 'lbp'

for f in files_list:
    #f = files_list[0]
    ds = pd.read_csv(f, header=0)
    print(ds.shape, f)

    data_hog = []
    tic = time.clock()
    savefile = False
    for index, row in ds.iterrows():
        if feature_desc == 'lbp':
            calculate_lbp(row)
        else:
            calculate_hog(row)
    print(time.clock() - tic)

    if len(data_hog) > 0:
        print(len(data_hog[0]))
        # save file
        df = pd.DataFrame(data_hog)
        filename = 'features_{:s}_{:s}_{:d}.csv'.format(feature_desc, ds['person'][0],ds['class'][0])
        df.to_csv(filename, index=False, encoding='utf-8')
# Out:
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p002_1.csv
# E:\MestradoData\p002\02_1_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p002\02_1_depth_11.bmp 5.6705365566130865
# E:\MestradoData\p002\02_1_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p002\02_1_depth_21.bmp 5.860787468019765
# E:\MestradoData\p002\02_1_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p002\02_1_depth_31.bmp 5.531291629596751
# E:\MestradoData\p002\02_1_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p002\02_1_depth_41.bmp 5.37569866611463
# E:\MestradoData\p002\02_1_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p002\02_1_depth_51.bmp 5.360673690331879
# E:\MestradoData\p002\02_1_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p002\02_1_depth_61.bmp 5.4632897080180385
# E:\MestradoData\p002\02_1_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p002\02_1_depth_71.bmp 5.563712344721125
# E:\MestradoData\p002\02_1_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p002\02_1_depth_81.bmp 6.00863051169938
# E:\MestradoData\p002\02_1_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p002\02_1_depth_91.bmp 6.376130468242593
# E:\MestradoData\p002\02_1_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p002\02_1_depth_101.bmp 8.48210016229126
# E:\MestradoData\p002\02_1_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p002\02_1_depth_111.bmp 5.749199605570709
# E:\MestradoData\p002\02_1_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p002\02_1_depth_121.bmp 5.627945380388837
# E:\MestradoData\p002\02_1_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p002\02_1_depth_131.bmp 5.556349980167909
# E:\MestradoData\p002\02_1_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p002\02_1_depth_141.bmp 5.532357900359216
# E:\MestradoData\p002\02_1_depth_161.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p002\02_1_depth_161.bmp 5.538253401873817
# 87.70364902427733
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p002_10.csv
# E:\MestradoData\p002\02_10_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p002\02_10_depth_1.bmp 5.500547160061501
# E:\MestradoData\p002\02_10_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p002\02_10_depth_11.bmp 5.475796167272165
# E:\MestradoData\p002\02_10_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p002\02_10_depth_21.bmp 5.436673630282598
# E:\MestradoData\p002\02_10_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p002\02_10_depth_31.bmp 5.404797704851205
# E:\MestradoData\p002\02_10_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p002\02_10_depth_41.bmp 5.457863934527268
# E:\MestradoData\p002\02_10_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p002\02_10_depth_51.bmp 6.123880198415634
# E:\MestradoData\p002\02_10_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p002\02_10_depth_61.bmp 5.52615820155404
# E:\MestradoData\p002\02_10_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p002\02_10_depth_71.bmp 5.505180045289819
# E:\MestradoData\p002\02_10_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p002\02_10_depth_81.bmp 5.501595257998815
# E:\MestradoData\p002\02_10_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p002\02_10_depth_91.bmp 5.489709835291023
# E:\MestradoData\p002\02_10_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p002\02_10_depth_101.bmp 5.471885849374132
# E:\MestradoData\p002\02_10_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p002\02_10_depth_121.bmp 5.67009764337962
# E:\MestradoData\p002\02_10_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p002\02_10_depth_131.bmp 5.477537597994967
# E:\MestradoData\p002\02_10_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p002\02_10_depth_141.bmp 5.523010352189317
# E:\MestradoData\p002\02_10_depth_151.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p002\02_10_depth_151.bmp 5.762147743488242
# 83.33111282479973
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p002_11.csv
# E:\MestradoData\p002\02_11_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p002\02_11_depth_1.bmp 5.764123050569481
# E:\MestradoData\p002\02_11_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p002\02_11_depth_11.bmp 7.084448328337146
# E:\MestradoData\p002\02_11_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p002\02_11_depth_21.bmp 5.834106995273487
# E:\MestradoData\p002\02_11_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p002\02_11_depth_31.bmp 5.676273638499822
# E:\MestradoData\p002\02_11_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p002\02_11_depth_41.bmp 6.690354022436338
# E:\MestradoData\p002\02_11_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p002\02_11_depth_51.bmp 5.4486475467476225
# E:\MestradoData\p002\02_11_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p002\02_11_depth_61.bmp 5.7147660525305355
# E:\MestradoData\p002\02_11_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p002\02_11_depth_71.bmp 6.181366770278089
# E:\MestradoData\p002\02_11_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p002\02_11_depth_81.bmp 6.182208646156141
# E:\MestradoData\p002\02_11_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p002\02_11_depth_91.bmp 5.41108510729083
# E:\MestradoData\p002\02_11_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p002\02_11_depth_101.bmp 5.464186497432877
# E:\MestradoData\p002\02_11_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p002\02_11_depth_111.bmp 5.515317321230782
# E:\MestradoData\p002\02_11_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p002\02_11_depth_131.bmp 5.604796361642343
# E:\MestradoData\p002\02_11_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p002\02_11_depth_141.bmp 5.455898108919996
# E:\MestradoData\p002\02_11_depth_151.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p002\02_11_depth_151.bmp 5.509033079282517
# 87.5411310292298
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p002_12.csv
# E:\MestradoData\p002\02_12_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p002\02_12_depth_1.bmp 5.650431091017424
# E:\MestradoData\p002\02_12_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p002\02_12_depth_11.bmp 6.494672991863354
# E:\MestradoData\p002\02_12_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p002\02_12_depth_21.bmp 6.147606401891267
# E:\MestradoData\p002\02_12_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p002\02_12_depth_31.bmp 5.458472329108304
# E:\MestradoData\p002\02_12_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p002\02_12_depth_41.bmp 5.384625868937633
# E:\MestradoData\p002\02_12_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p002\02_12_depth_51.bmp 5.454933368941624
# E:\MestradoData\p002\02_12_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p002\02_12_depth_61.bmp 5.627261529077259
# E:\MestradoData\p002\02_12_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p002\02_12_depth_71.bmp 5.599007526710125
# E:\MestradoData\p002\02_12_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p002\02_12_depth_81.bmp 5.648746154077003
# E:\MestradoData\p002\02_12_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p002\02_12_depth_91.bmp 5.560246865977888
# E:\MestradoData\p002\02_12_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p002\02_12_depth_101.bmp 5.464578793419264
# E:\MestradoData\p002\02_12_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p002\02_12_depth_111.bmp 5.433125188641839
# E:\MestradoData\p002\02_12_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p002\02_12_depth_121.bmp 5.530476617895033
# E:\MestradoData\p002\02_12_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p002\02_12_depth_131.bmp 5.4387398014895325
# E:\MestradoData\p002\02_12_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p002\02_12_depth_141.bmp 5.364262823298532
# 84.26162784266438
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p002_13.csv
# E:\MestradoData\p002\02_13_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p002\02_13_depth_1.bmp 5.566843206444901
# E:\MestradoData\p002\02_13_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p002\02_13_depth_11.bmp 5.509082857020985
# E:\MestradoData\p002\02_13_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p002\02_13_depth_21.bmp 5.467813951356902
# E:\MestradoData\p002\02_13_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p002\02_13_depth_31.bmp 5.4985102233993075
# E:\MestradoData\p002\02_13_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p002\02_13_depth_41.bmp 5.728186288840448
# E:\MestradoData\p002\02_13_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p002\02_13_depth_51.bmp 5.447340683582638
# E:\MestradoData\p002\02_13_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p002\02_13_depth_61.bmp 5.531453209716005
# E:\MestradoData\p002\02_13_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p002\02_13_depth_71.bmp 5.763324236385756
# E:\MestradoData\p002\02_13_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p002\02_13_depth_81.bmp 5.391634653523283
# E:\MestradoData\p002\02_13_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p002\02_13_depth_91.bmp 5.458216329310517
# E:\MestradoData\p002\02_13_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p002\02_13_depth_101.bmp 5.376261628632733
# E:\MestradoData\p002\02_13_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p002\02_13_depth_111.bmp 5.471345800418135
# E:\MestradoData\p002\02_13_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p002\02_13_depth_121.bmp 5.569458908081856
# E:\MestradoData\p002\02_13_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p002\02_13_depth_131.bmp 5.488269836428799
# E:\MestradoData\p002\02_13_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p002\02_13_depth_141.bmp 5.663477204166156
# 82.93585664327384
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p002_14.csv
# E:\MestradoData\p002\02_14_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p002\02_14_depth_1.bmp 5.427425637589522
# E:\MestradoData\p002\02_14_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p002\02_14_depth_11.bmp 5.569147204624414
# E:\MestradoData\p002\02_14_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p002\02_14_depth_21.bmp 5.527167188411113
# E:\MestradoData\p002\02_14_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p002\02_14_depth_31.bmp 5.495255707452316
# E:\MestradoData\p002\02_14_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p002\02_14_depth_51.bmp 5.570146314946101
# E:\MestradoData\p002\02_14_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p002\02_14_depth_61.bmp 5.524851338388999
# E:\MestradoData\p002\02_14_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p002\02_14_depth_71.bmp 5.4778232273989715
# E:\MestradoData\p002\02_14_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p002\02_14_depth_81.bmp 5.592009408782701
# E:\MestradoData\p002\02_14_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p002\02_14_depth_91.bmp 5.570073623645499
# E:\MestradoData\p002\02_14_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p002\02_14_depth_101.bmp 5.310920445692432
# E:\MestradoData\p002\02_14_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p002\02_14_depth_111.bmp 5.309228397646734
# E:\MestradoData\p002\02_14_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p002\02_14_depth_121.bmp 5.821420388013621
# E:\MestradoData\p002\02_14_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p002\02_14_depth_131.bmp 5.387985471221441
# E:\MestradoData\p002\02_14_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p002\02_14_depth_141.bmp 5.775806201832097
# E:\MestradoData\p002\02_14_depth_151.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p002\02_14_depth_151.bmp 5.637166903966886
# 83.00044760458468
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p002_15.csv
# E:\MestradoData\p002\02_15_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p002\02_15_depth_1.bmp 6.557137337570566
# E:\MestradoData\p002\02_15_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p002\02_15_depth_11.bmp 6.672930233734064
# E:\MestradoData\p002\02_15_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p002\02_15_depth_21.bmp 6.598841600915307
# E:\MestradoData\p002\02_15_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p002\02_15_depth_31.bmp 7.195969425406929
# E:\MestradoData\p002\02_15_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p002\02_15_depth_41.bmp 6.578956974651305
# E:\MestradoData\p002\02_15_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p002\02_15_depth_51.bmp 6.684004200292975
# E:\MestradoData\p002\02_15_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p002\02_15_depth_61.bmp 6.463906003827333
# E:\MestradoData\p002\02_15_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p002\02_15_depth_71.bmp 6.269598206737328
# E:\MestradoData\p002\02_15_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p002\02_15_depth_81.bmp 6.284384170363182
# E:\MestradoData\p002\02_15_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p002\02_15_depth_91.bmp 6.281203530900939
# E:\MestradoData\p002\02_15_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p002\02_15_depth_101.bmp 6.2633289771227965
# E:\MestradoData\p002\02_15_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p002\02_15_depth_111.bmp 6.599177403119029
# E:\MestradoData\p002\02_15_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p002\02_15_depth_121.bmp 6.100313204690792
# E:\MestradoData\p002\02_15_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p002\02_15_depth_131.bmp 6.365434180397756
# E:\MestradoData\p002\02_15_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p002\02_15_depth_141.bmp 6.115080205368713
# 97.03508303400838
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p002_16.csv
# E:\MestradoData\p002\02_16_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p002\02_16_depth_1.bmp 6.437747012150567
# E:\MestradoData\p002\02_16_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p002\02_16_depth_11.bmp 5.9872407014394184
# E:\MestradoData\p002\02_16_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p002\02_16_depth_21.bmp 6.256704587295189
# E:\MestradoData\p002\02_16_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p002\02_16_depth_31.bmp 6.148904968766374
# E:\MestradoData\p002\02_16_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p002\02_16_depth_41.bmp 6.173060604001421
# E:\MestradoData\p002\02_16_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p002\02_16_depth_61.bmp 6.260961769116648
# E:\MestradoData\p002\02_16_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p002\02_16_depth_71.bmp 5.9949459793018605
# E:\MestradoData\p002\02_16_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p002\02_16_depth_81.bmp 6.009292239571664
# E:\MestradoData\p002\02_16_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p002\02_16_depth_91.bmp 5.976220463233176
# E:\MestradoData\p002\02_16_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p002\02_16_depth_101.bmp 5.927890229815148
# E:\MestradoData\p002\02_16_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p002\02_16_depth_111.bmp 6.1994238424305195
# E:\MestradoData\p002\02_16_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p002\02_16_depth_121.bmp 6.481106582829398
# E:\MestradoData\p002\02_16_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p002\02_16_depth_131.bmp 6.081513022014406
# E:\MestradoData\p002\02_16_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p002\02_16_depth_141.bmp 6.27630318909371
# E:\MestradoData\p002\02_16_depth_151.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p002\02_16_depth_151.bmp 6.2250028839483775
# 92.44119668843723
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p002_17.csv
# E:\MestradoData\p002\02_17_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p002\02_17_depth_1.bmp 5.978205646849801
# E:\MestradoData\p002\02_17_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p002\02_17_depth_11.bmp 6.179678277785001
# E:\MestradoData\p002\02_17_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p002\02_17_depth_31.bmp 6.334069464438926
# E:\MestradoData\p002\02_17_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p002\02_17_depth_41.bmp 6.037110884258027
# E:\MestradoData\p002\02_17_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p002\02_17_depth_51.bmp 6.444917771916835
# E:\MestradoData\p002\02_17_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p002\02_17_depth_61.bmp 6.087646350501586
# E:\MestradoData\p002\02_17_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p002\02_17_depth_71.bmp 6.1130772439883
# E:\MestradoData\p002\02_17_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p002\02_17_depth_81.bmp 6.176861489887301
# E:\MestradoData\p002\02_17_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p002\02_17_depth_91.bmp 6.001151604028337
# E:\MestradoData\p002\02_17_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p002\02_17_depth_101.bmp 6.099934340792629
# E:\MestradoData\p002\02_17_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p002\02_17_depth_111.bmp 6.3219446345128745
# E:\MestradoData\p002\02_17_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p002\02_17_depth_121.bmp 6.208538304364765
# E:\MestradoData\p002\02_17_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p002\02_17_depth_131.bmp 5.989511119398685
# E:\MestradoData\p002\02_17_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p002\02_17_depth_141.bmp 6.103317646761411
# E:\MestradoData\p002\02_17_depth_151.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p002\02_17_depth_151.bmp 6.092795185939622
# 92.17353665300811
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p002_18.csv
# E:\MestradoData\p002\02_18_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p002\02_18_depth_1.bmp 6.031647184871304
# E:\MestradoData\p002\02_18_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p002\02_18_depth_11.bmp 6.454895443045643
# E:\MestradoData\p002\02_18_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p002\02_18_depth_21.bmp 6.0113512996731515
# E:\MestradoData\p002\02_18_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p002\02_18_depth_31.bmp 5.999574913916149
# E:\MestradoData\p002\02_18_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p002\02_18_depth_41.bmp 6.189364393588676
# E:\MestradoData\p002\02_18_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p002\02_18_depth_51.bmp 6.478535918193984
# E:\MestradoData\p002\02_18_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p002\02_18_depth_61.bmp 6.997884841177438
# E:\MestradoData\p002\02_18_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p002\02_18_depth_71.bmp 6.154867235660504
# E:\MestradoData\p002\02_18_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p002\02_18_depth_81.bmp 5.719574740089229
# E:\MestradoData\p002\02_18_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p002\02_18_depth_91.bmp 5.892543294780808
# E:\MestradoData\p002\02_18_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p002\02_18_depth_101.bmp 6.77729716361705
# E:\MestradoData\p002\02_18_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p002\02_18_depth_111.bmp 6.088312424049491
# E:\MestradoData\p002\02_18_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p002\02_18_depth_121.bmp 5.9389124433284906
# E:\MestradoData\p002\02_18_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p002\02_18_depth_131.bmp 6.056875806913013
# E:\MestradoData\p002\02_18_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p002\02_18_depth_141.bmp 6.1678734476063255
# 92.96320595499765
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p002_19.csv
# E:\MestradoData\p002\02_19_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p002\02_19_depth_1.bmp 6.968474098983506
# E:\MestradoData\p002\02_19_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p002\02_19_depth_21.bmp 7.043105151126838
# E:\MestradoData\p002\02_19_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p002\02_19_depth_31.bmp 6.9010572633621905
# E:\MestradoData\p002\02_19_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p002\02_19_depth_41.bmp 6.192088737115228
# E:\MestradoData\p002\02_19_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p002\02_19_depth_51.bmp 6.804643314849727
# E:\MestradoData\p002\02_19_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p002\02_19_depth_61.bmp 7.4992659758886475
# E:\MestradoData\p002\02_19_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p002\02_19_depth_71.bmp 6.526460423537401
# E:\MestradoData\p002\02_19_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p002\02_19_depth_81.bmp 6.226284858244071
# E:\MestradoData\p002\02_19_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p002\02_19_depth_91.bmp 6.070530314642838
# E:\MestradoData\p002\02_19_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p002\02_19_depth_101.bmp 6.219095135529642
# E:\MestradoData\p002\02_19_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p002\02_19_depth_111.bmp 6.007157722739521
# E:\MestradoData\p002\02_19_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p002\02_19_depth_121.bmp 6.243780943185357
# E:\MestradoData\p002\02_19_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p002\02_19_depth_131.bmp 6.112940947799643
# E:\MestradoData\p002\02_19_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p002\02_19_depth_141.bmp 6.355005744193022
# E:\MestradoData\p002\02_19_depth_151.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p002\02_19_depth_151.bmp 6.357957248033699
# 97.53260757917428
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p002_2.csv
# E:\MestradoData\p002\02_2_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p002\02_2_depth_1.bmp 6.411642934010615
# E:\MestradoData\p002\02_2_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p002\02_2_depth_11.bmp 6.572673127764347
# E:\MestradoData\p002\02_2_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p002\02_2_depth_21.bmp 6.473811378716846
# E:\MestradoData\p002\02_2_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p002\02_2_depth_31.bmp 6.220815627997354
# E:\MestradoData\p002\02_2_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p002\02_2_depth_41.bmp 6.174909886490923
# E:\MestradoData\p002\02_2_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p002\02_2_depth_51.bmp 6.42098218589058
# E:\MestradoData\p002\02_2_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p002\02_2_depth_61.bmp 6.109543419619968
# E:\MestradoData\p002\02_2_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p002\02_2_depth_71.bmp 6.195164685301961
# E:\MestradoData\p002\02_2_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p002\02_2_depth_81.bmp 5.908441751354758
# E:\MestradoData\p002\02_2_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p002\02_2_depth_91.bmp 6.347041701102853
# E:\MestradoData\p002\02_2_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p002\02_2_depth_101.bmp 6.258598906786119
# E:\MestradoData\p002\02_2_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p002\02_2_depth_111.bmp 5.834912130439761
# E:\MestradoData\p002\02_2_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p002\02_2_depth_121.bmp 5.934286669205449
# E:\MestradoData\p002\02_2_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p002\02_2_depth_131.bmp 5.797139518309677
# E:\MestradoData\p002\02_2_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p002\02_2_depth_141.bmp 5.652438003012094
# 92.31708814452281
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p002_3.csv
# E:\MestradoData\p002\02_3_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p002\02_3_depth_21.bmp 5.634757424389136
# E:\MestradoData\p002\02_3_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p002\02_3_depth_31.bmp 5.882764734605644
# E:\MestradoData\p002\02_3_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p002\02_3_depth_41.bmp 5.634661424465094
# E:\MestradoData\p002\02_3_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p002\02_3_depth_51.bmp 5.662729352905217
# E:\MestradoData\p002\02_3_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p002\02_3_depth_61.bmp 5.6820304734574165
# E:\MestradoData\p002\02_3_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p002\02_3_depth_71.bmp 5.601612561688626
# E:\MestradoData\p002\02_3_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p002\02_3_depth_81.bmp 5.754708341958803
# E:\MestradoData\p002\02_3_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p002\02_3_depth_91.bmp 5.676062675703633
# E:\MestradoData\p002\02_3_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p002\02_3_depth_101.bmp 6.016169468705584
# E:\MestradoData\p002\02_3_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p002\02_3_depth_111.bmp 6.870340053064638
# E:\MestradoData\p002\02_3_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p002\02_3_depth_121.bmp 6.044743865881401
# E:\MestradoData\p002\02_3_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p002\02_3_depth_131.bmp 6.000465777409772
# E:\MestradoData\p002\02_3_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p002\02_3_depth_141.bmp 5.528439286171533
# E:\MestradoData\p002\02_3_depth_151.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p002\02_3_depth_151.bmp 5.581593219481874
# E:\MestradoData\p002\02_3_depth_171.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p002\02_3_depth_171.bmp 5.5960670845890945
# 87.17096164269697
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p002_4.csv
# E:\MestradoData\p002\02_4_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p002\02_4_depth_1.bmp 5.910087577214654
# E:\MestradoData\p002\02_4_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p002\02_4_depth_11.bmp 5.560137433965565
# E:\MestradoData\p002\02_4_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p002\02_4_depth_21.bmp 5.747819260982169
# E:\MestradoData\p002\02_4_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p002\02_4_depth_31.bmp 5.483868852251817
# E:\MestradoData\p002\02_4_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p002\02_4_depth_41.bmp 5.669240755167721
# E:\MestradoData\p002\02_4_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p002\02_4_depth_51.bmp 5.675974577007764
# E:\MestradoData\p002\02_4_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p002\02_4_depth_61.bmp 5.656202148185912
# E:\MestradoData\p002\02_4_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p002\02_4_depth_81.bmp 5.840556372893843
# E:\MestradoData\p002\02_4_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p002\02_4_depth_91.bmp 5.886682163609294
# E:\MestradoData\p002\02_4_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p002\02_4_depth_101.bmp 5.767227443178399
# E:\MestradoData\p002\02_4_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p002\02_4_depth_111.bmp 5.6334904624272895
# E:\MestradoData\p002\02_4_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p002\02_4_depth_121.bmp 5.385271004230162
# E:\MestradoData\p002\02_4_depth_151.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p002\02_4_depth_151.bmp 5.578549666331128
# E:\MestradoData\p002\02_4_depth_161.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p002\02_4_depth_161.bmp 5.562231259471673
# E:\MestradoData\p002\02_4_depth_171.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p002\02_4_depth_171.bmp 5.471279035038833
# 84.8332655144568
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p002_5.csv
# E:\MestradoData\p002\02_5_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p002\02_5_depth_1.bmp 5.47525295782475
# E:\MestradoData\p002\02_5_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p002\02_5_depth_11.bmp 5.351048413986518
# E:\MestradoData\p002\02_5_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p002\02_5_depth_21.bmp 5.611141443048609
# E:\MestradoData\p002\02_5_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p002\02_5_depth_31.bmp 5.502324936434661
# E:\MestradoData\p002\02_5_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p002\02_5_depth_41.bmp 5.625476641598652
# E:\MestradoData\p002\02_5_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p002\02_5_depth_51.bmp 5.531547629394481
# E:\MestradoData\p002\02_5_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p002\02_5_depth_61.bmp 5.622528298249108
# E:\MestradoData\p002\02_5_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p002\02_5_depth_71.bmp 5.5756748044050255
# E:\MestradoData\p002\02_5_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p002\02_5_depth_81.bmp 5.707641514949955
# E:\MestradoData\p002\02_5_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p002\02_5_depth_91.bmp 5.555539709203003
# E:\MestradoData\p002\02_5_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p002\02_5_depth_111.bmp 5.492406129456867
# E:\MestradoData\p002\02_5_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p002\02_5_depth_121.bmp 5.617732252656197
# E:\MestradoData\p002\02_5_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p002\02_5_depth_131.bmp 5.467524371338641
# E:\MestradoData\p002\02_5_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p002\02_5_depth_141.bmp 5.378177676501764
# E:\MestradoData\p002\02_5_depth_151.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p002\02_5_depth_151.bmp 5.6168654879088535
# 83.13482695519838
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p002_6.csv
# E:\MestradoData\p002\02_6_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p002\02_6_depth_1.bmp 5.492118129684513
# E:\MestradoData\p002\02_6_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p002\02_6_depth_11.bmp 5.650040375276831
# E:\MestradoData\p002\02_6_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p002\02_6_depth_21.bmp 5.421963518448592
# E:\MestradoData\p002\02_6_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p002\02_6_depth_31.bmp 5.567372193681194
# E:\MestradoData\p002\02_6_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p002\02_6_depth_41.bmp 5.603608016902172
# E:\MestradoData\p002\02_6_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p002\02_6_depth_51.bmp 5.48006401575185
# E:\MestradoData\p002\02_6_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p002\02_6_depth_61.bmp 5.617342327038159
# E:\MestradoData\p002\02_6_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p002\02_6_depth_71.bmp 5.409461799931478
# E:\MestradoData\p002\02_6_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p002\02_6_depth_81.bmp 6.659425454281063
# E:\MestradoData\p002\02_6_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p002\02_6_depth_91.bmp 5.526365213735971
# E:\MestradoData\p002\02_6_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p002\02_6_depth_101.bmp 5.475254933131964
# E:\MestradoData\p002\02_6_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p002\02_6_depth_111.bmp 5.52349469748583
# E:\MestradoData\p002\02_6_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p002\02_6_depth_121.bmp 5.433832743638277
# E:\MestradoData\p002\02_6_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p002\02_6_depth_131.bmp 5.634451646852995
# E:\MestradoData\p002\02_6_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p002\02_6_depth_141.bmp 5.487885441670869
# 83.9871636644632
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p002_7.csv
# E:\MestradoData\p002\02_7_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p002\02_7_depth_1.bmp 5.529492914968614
# E:\MestradoData\p002\02_7_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p002\02_7_depth_11.bmp 5.537656859135495
# E:\MestradoData\p002\02_7_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p002\02_7_depth_21.bmp 5.4926348700169
# E:\MestradoData\p002\02_7_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p002\02_7_depth_31.bmp 5.351673006085548
# E:\MestradoData\p002\02_7_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p002\02_7_depth_41.bmp 5.523374203753747
# E:\MestradoData\p002\02_7_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p002\02_7_depth_51.bmp 5.487566232046447
# E:\MestradoData\p002\02_7_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p002\02_7_depth_61.bmp 5.348289700116766
# E:\MestradoData\p002\02_7_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p002\02_7_depth_71.bmp 5.525331733071198
# E:\MestradoData\p002\02_7_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p002\02_7_depth_81.bmp 5.420849840316123
# E:\MestradoData\p002\02_7_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p002\02_7_depth_91.bmp 5.513306458622083
# E:\MestradoData\p002\02_7_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p002\02_7_depth_101.bmp 5.592686148988605
# E:\MestradoData\p002\02_7_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p002\02_7_depth_111.bmp 5.508509622905876
# E:\MestradoData\p002\02_7_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p002\02_7_depth_121.bmp 5.469978097795092
# E:\MestradoData\p002\02_7_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p002\02_7_depth_131.bmp 5.4912904760174115
# E:\MestradoData\p002\02_7_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p002\02_7_depth_141.bmp 5.573921521839793
# 82.3715062743654
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p002_8.csv
# E:\MestradoData\p002\02_8_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p002\02_8_depth_1.bmp 5.5908945454659715
# E:\MestradoData\p002\02_8_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p002\02_8_depth_11.bmp 5.674354825200908
# E:\MestradoData\p002\02_8_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p002\02_8_depth_21.bmp 5.5963313806764745
# E:\MestradoData\p002\02_8_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p002\02_8_depth_31.bmp 5.575344928122604
# E:\MestradoData\p002\02_8_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p002\02_8_depth_41.bmp 5.4723121206423
# E:\MestradoData\p002\02_8_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p002\02_8_depth_51.bmp 5.444128439207134
# E:\MestradoData\p002\02_8_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p002\02_8_depth_61.bmp 5.505914069401115
# E:\MestradoData\p002\02_8_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p002\02_8_depth_71.bmp 5.564498516939466
# E:\MestradoData\p002\02_8_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p002\02_8_depth_81.bmp 5.583107094829074
# E:\MestradoData\p002\02_8_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p002\02_8_depth_91.bmp 5.585784426046757
# E:\MestradoData\p002\02_8_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p002\02_8_depth_101.bmp 5.4016838307682065
# E:\MestradoData\p002\02_8_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p002\02_8_depth_111.bmp 5.379340342249634
# E:\MestradoData\p002\02_8_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p002\02_8_depth_121.bmp 5.598522391290999
# E:\MestradoData\p002\02_8_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p002\02_8_depth_131.bmp 5.293715521014747
# E:\MestradoData\p002\02_8_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p002\02_8_depth_141.bmp 5.385559004002744
# 82.65578496333023
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p002_9.csv
# E:\MestradoData\p002\02_9_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p002\02_9_depth_1.bmp 5.348958144033077
# E:\MestradoData\p002\02_9_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p002\02_9_depth_11.bmp 5.370575904730231
# E:\MestradoData\p002\02_9_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p002\02_9_depth_21.bmp 5.338944917376921
# E:\MestradoData\p002\02_9_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p002\02_9_depth_31.bmp 5.457417910188269
# E:\MestradoData\p002\02_9_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p002\02_9_depth_41.bmp 5.543751866665161
# E:\MestradoData\p002\02_9_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p002\02_9_depth_51.bmp 5.537111279319561
# E:\MestradoData\p002\02_9_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p002\02_9_depth_61.bmp 5.615073094263153
# E:\MestradoData\p002\02_9_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p002\02_9_depth_71.bmp 5.532996319607946
# E:\MestradoData\p002\02_9_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p002\02_9_depth_81.bmp 5.493810572791517
# E:\MestradoData\p002\02_9_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p002\02_9_depth_91.bmp 5.482370779361418
# E:\MestradoData\p002\02_9_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p002\02_9_depth_101.bmp 5.39469874986753
# E:\MestradoData\p002\02_9_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p002\02_9_depth_111.bmp 5.489867859857441
# E:\MestradoData\p002\02_9_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p002\02_9_depth_121.bmp 5.460205068479809
# E:\MestradoData\p002\02_9_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p002\02_9_depth_131.bmp 5.597637848779868
# E:\MestradoData\p002\02_9_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p002\02_9_depth_141.bmp 5.582330009023053
# 82.25089994990617
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p003_1.csv
# E:\MestradoData\p003\3_1_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p003\3_1_depth_1.bmp 5.576365766821937
# E:\MestradoData\p003\3_1_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p003\3_1_depth_11.bmp 5.58523884623105
# E:\MestradoData\p003\3_1_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p003\3_1_depth_21.bmp 5.559012694113562
# E:\MestradoData\p003\3_1_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p003\3_1_depth_31.bmp 5.513663594142372
# E:\MestradoData\p003\3_1_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p003\3_1_depth_41.bmp 5.557411510193333
# E:\MestradoData\p003\3_1_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p003\3_1_depth_51.bmp 5.620648991092139
# E:\MestradoData\p003\3_1_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p003\3_1_depth_61.bmp 5.724563575653519
# E:\MestradoData\p003\3_1_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p003\3_1_depth_71.bmp 5.690960836771637
# E:\MestradoData\p003\3_1_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p003\3_1_depth_81.bmp 5.95718403382989
# E:\MestradoData\p003\3_1_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p003\3_1_depth_91.bmp 5.529328964480783
# E:\MestradoData\p003\3_1_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p003\3_1_depth_101.bmp 5.7551824156582825
# E:\MestradoData\p003\3_1_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p003\3_1_depth_111.bmp 5.608580654948582
# E:\MestradoData\p003\3_1_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p003\3_1_depth_131.bmp 5.5146145069711565
# E:\MestradoData\p003\3_1_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p003\3_1_depth_141.bmp 5.738232700655544
# E:\MestradoData\p003\3_1_depth_151.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p003\3_1_depth_151.bmp 5.651630102415766
# 84.5886296583667
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p003_10.csv
# E:\MestradoData\p003\3_10_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p003\3_10_depth_1.bmp 5.862319911253508
# E:\MestradoData\p003\3_10_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p003\3_10_depth_11.bmp 5.542446583745914
# E:\MestradoData\p003\3_10_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p003\3_10_depth_21.bmp 5.5957901465360464
# E:\MestradoData\p003\3_10_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p003\3_10_depth_31.bmp 5.83805642425159
# E:\MestradoData\p003\3_10_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p003\3_10_depth_41.bmp 5.679231068261743
# E:\MestradoData\p003\3_10_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p003\3_10_depth_51.bmp 5.75328809616758
# E:\MestradoData\p003\3_10_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p003\3_10_depth_61.bmp 5.44510305572112
# E:\MestradoData\p003\3_10_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p003\3_10_depth_71.bmp 5.554960944228469
# E:\MestradoData\p003\3_10_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p003\3_10_depth_91.bmp 5.715001904196015
# E:\MestradoData\p003\3_10_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p003\3_10_depth_101.bmp 5.382895104872887
# E:\MestradoData\p003\3_10_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p003\3_10_depth_111.bmp 5.521493711412404
# E:\MestradoData\p003\3_10_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p003\3_10_depth_121.bmp 5.65256402760383
# E:\MestradoData\p003\3_10_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p003\3_10_depth_131.bmp 5.521104575917207
# E:\MestradoData\p003\3_10_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p003\3_10_depth_141.bmp 5.551871168891921
# E:\MestradoData\p003\3_10_depth_151.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p003\3_10_depth_151.bmp 5.594434690816797
# 84.21576160729933
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p003_11.csv
# E:\MestradoData\p003\3_11_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p003\3_11_depth_1.bmp 5.425835515388826
# E:\MestradoData\p003\3_11_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p003\3_11_depth_11.bmp 5.609605444262343
# E:\MestradoData\p003\3_11_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p003\3_11_depth_21.bmp 5.375720394492419
# E:\MestradoData\p003\3_11_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p003\3_11_depth_31.bmp 5.4660010145175875
# E:\MestradoData\p003\3_11_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p003\3_11_depth_41.bmp 5.539045500013344
# E:\MestradoData\p003\3_11_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p003\3_11_depth_51.bmp 5.555396301909241
# E:\MestradoData\p003\3_11_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p003\3_11_depth_61.bmp 5.488567712736767
# E:\MestradoData\p003\3_11_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p003\3_11_depth_71.bmp 5.320402709805421
# E:\MestradoData\p003\3_11_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p003\3_11_depth_81.bmp 5.60148930252717
# E:\MestradoData\p003\3_11_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p003\3_11_depth_91.bmp 5.5769271490948995
# E:\MestradoData\p003\3_11_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p003\3_11_depth_101.bmp 5.372337483585397
# E:\MestradoData\p003\3_11_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p003\3_11_depth_111.bmp 5.638935593927727
# E:\MestradoData\p003\3_11_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p003\3_11_depth_121.bmp 5.650781115432437
# E:\MestradoData\p003\3_11_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p003\3_11_depth_131.bmp 5.89012867940437
# E:\MestradoData\p003\3_11_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p003\3_11_depth_141.bmp 5.68647451932884
# 83.20311727161106
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p003_12.csv
# E:\MestradoData\p003\3_12_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p003\3_12_depth_1.bmp 5.853887720385046
# E:\MestradoData\p003\3_12_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p003\3_12_depth_11.bmp 5.763643050948758
# E:\MestradoData\p003\3_12_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p003\3_12_depth_21.bmp 5.499888987741997
# E:\MestradoData\p003\3_12_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p003\3_12_depth_31.bmp 5.819513821618784
# E:\MestradoData\p003\3_12_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p003\3_12_depth_41.bmp 5.369042671373791
# E:\MestradoData\p003\3_12_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p003\3_12_depth_51.bmp 5.529571532190403
# E:\MestradoData\p003\3_12_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p003\3_12_depth_61.bmp 5.502844837258181
# E:\MestradoData\p003\3_12_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p003\3_12_depth_71.bmp 5.4286677106824754
# E:\MestradoData\p003\3_12_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p003\3_12_depth_81.bmp 5.473003083059211
# E:\MestradoData\p003\3_12_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p003\3_12_depth_91.bmp 5.719054444203721
# E:\MestradoData\p003\3_12_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p003\3_12_depth_101.bmp 5.613391712875455
# E:\MestradoData\p003\3_12_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p003\3_12_depth_111.bmp 5.568544340903372
# E:\MestradoData\p003\3_12_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p003\3_12_depth_121.bmp 5.591572075794829
# E:\MestradoData\p003\3_12_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# ...
# E:\MestradoData\p003\3_6_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p003\3_6_depth_41.bmp 5.601164957104174
# E:\MestradoData\p003\3_6_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p003\3_6_depth_51.bmp 6.639207396181973
# E:\MestradoData\p003\3_6_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p003\3_6_depth_61.bmp 5.564405677506784
# E:\MestradoData\p003\3_6_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p003\3_6_depth_71.bmp 5.550371515756069
# E:\MestradoData\p003\3_6_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p003\3_6_depth_81.bmp 5.978964559830274
# E:\MestradoData\p003\3_6_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p003\3_6_depth_91.bmp 5.6090993705879555
# E:\MestradoData\p003\3_6_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p003\3_6_depth_101.bmp 5.716751631208808
# E:\MestradoData\p003\3_6_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p003\3_6_depth_111.bmp 5.933373682272759
# E:\MestradoData\p003\3_6_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p003\3_6_depth_121.bmp 6.728542239176477
# E:\MestradoData\p003\3_6_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p003\3_6_depth_131.bmp 6.087934350273827
# E:\MestradoData\p003\3_6_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p003\3_6_depth_141.bmp 5.748184297730859
# 89.33887143595348
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p003_7.csv
# E:\MestradoData\p003\3_7_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p003\3_7_depth_1.bmp 5.776902102200893
# E:\MestradoData\p003\3_7_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p003\3_7_depth_11.bmp 5.906871777286597
# E:\MestradoData\p003\3_7_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p003\3_7_depth_21.bmp 6.194633327697375
# E:\MestradoData\p003\3_7_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p003\3_7_depth_31.bmp 5.763522557216675
# E:\MestradoData\p003\3_7_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p003\3_7_depth_41.bmp 5.7360136406805395
# E:\MestradoData\p003\3_7_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p003\3_7_depth_51.bmp 6.576000730073702
# E:\MestradoData\p003\3_7_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p003\3_7_depth_61.bmp 5.7563616739857935
# E:\MestradoData\p003\3_7_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p003\3_7_depth_71.bmp 5.907129357330177
# E:\MestradoData\p003\3_7_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p003\3_7_depth_81.bmp 5.748647309711032
# E:\MestradoData\p003\3_7_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p003\3_7_depth_91.bmp 6.291297350085642
# E:\MestradoData\p003\3_7_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p003\3_7_depth_101.bmp 5.909551873934561
# E:\MestradoData\p003\3_7_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p003\3_7_depth_111.bmp 5.708446255054696
# E:\MestradoData\p003\3_7_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p003\3_7_depth_121.bmp 5.946387005323686
# E:\MestradoData\p003\3_7_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p003\3_7_depth_131.bmp 6.07841850594059
# E:\MestradoData\p003\3_7_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p003\3_7_depth_141.bmp 5.852607721396453
# 89.1570361228355
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p003_8.csv
# E:\MestradoData\p003\3_8_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p003\3_8_depth_1.bmp 5.855449398163273
# E:\MestradoData\p003\3_8_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p003\3_8_depth_11.bmp 5.585178006772821
# E:\MestradoData\p003\3_8_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p003\3_8_depth_21.bmp 6.08348635378843
# E:\MestradoData\p003\3_8_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p003\3_8_depth_31.bmp 5.831477071425525
# E:\MestradoData\p003\3_8_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p003\3_8_depth_41.bmp 6.720573060288189
# E:\MestradoData\p003\3_8_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p003\3_8_depth_51.bmp 5.768362454627095
# E:\MestradoData\p003\3_8_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p003\3_8_depth_61.bmp 5.826950457717885
# E:\MestradoData\p003\3_8_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p003\3_8_depth_71.bmp 6.405577951148189
# E:\MestradoData\p003\3_8_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p003\3_8_depth_81.bmp 7.351428068007408
# E:\MestradoData\p003\3_8_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p003\3_8_depth_91.bmp 5.900784275923797
# E:\MestradoData\p003\3_8_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p003\3_8_depth_101.bmp 5.7086706499394495
# E:\MestradoData\p003\3_8_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p003\3_8_depth_111.bmp 6.257256093032538
# E:\MestradoData\p003\3_8_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p003\3_8_depth_121.bmp 5.784833355193314
# E:\MestradoData\p003\3_8_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p003\3_8_depth_131.bmp 5.558751953578849
# E:\MestradoData\p003\3_8_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p003\3_8_depth_141.bmp 5.554471463133268
# 90.19990660748135
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p003_9.csv
# E:\MestradoData\p003\3_9_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p003\3_9_depth_1.bmp 5.663212117955936
# E:\MestradoData\p003\3_9_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p003\3_9_depth_11.bmp 5.600927920254435
# E:\MestradoData\p003\3_9_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p003\3_9_depth_21.bmp 5.668896261612645
# E:\MestradoData\p003\3_9_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p003\3_9_depth_31.bmp 5.6505606711616565
# E:\MestradoData\p003\3_9_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p003\3_9_depth_41.bmp 6.354054436302704
# E:\MestradoData\p003\3_9_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p003\3_9_depth_51.bmp 6.557778522249009
# E:\MestradoData\p003\3_9_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p003\3_9_depth_61.bmp 5.704396085415283
# E:\MestradoData\p003\3_9_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p003\3_9_depth_71.bmp 6.230725743624134
# E:\MestradoData\p003\3_9_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p003\3_9_depth_81.bmp 5.556674720652154
# E:\MestradoData\p003\3_9_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p003\3_9_depth_91.bmp 5.532312468296368
# E:\MestradoData\p003\3_9_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p003\3_9_depth_101.bmp 5.504582317367294
# E:\MestradoData\p003\3_9_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p003\3_9_depth_111.bmp 5.488271021612945
# E:\MestradoData\p003\3_9_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p003\3_9_depth_121.bmp 5.5783718886937095
# E:\MestradoData\p003\3_9_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p003\3_9_depth_131.bmp 5.643913367772257
# E:\MestradoData\p003\3_9_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p003\3_9_depth_141.bmp 5.784937256345984
# 86.52461469660057
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p004_1.csv
# E:\MestradoData\p004\04_1_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p004\04_1_depth_1.bmp 5.664311968938819
# E:\MestradoData\p004\04_1_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p004\04_1_depth_11.bmp 5.7100968216518595
# E:\MestradoData\p004\04_1_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p004\04_1_depth_21.bmp 5.620223114885448
# E:\MestradoData\p004\04_1_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p004\04_1_depth_31.bmp 5.689506220637213
# E:\MestradoData\p004\04_1_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p004\04_1_depth_51.bmp 5.704816430762094
# E:\MestradoData\p004\04_1_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p004\04_1_depth_71.bmp 5.911471082294611
# E:\MestradoData\p004\04_1_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p004\04_1_depth_81.bmp 5.770684230570623
# E:\MestradoData\p004\04_1_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p004\04_1_depth_91.bmp 6.0327509864682725
# E:\MestradoData\p004\04_1_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p004\04_1_depth_111.bmp 5.6854090386891585
# E:\MestradoData\p004\04_1_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p004\04_1_depth_121.bmp 5.926151169460809
# E:\MestradoData\p004\04_1_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p004\04_1_depth_131.bmp 6.286261502213165
# E:\MestradoData\p004\04_1_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p004\04_1_depth_141.bmp 5.694544833940199
# E:\MestradoData\p004\04_1_depth_151.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p004\04_1_depth_151.bmp 5.752828639740528
# E:\MestradoData\p004\04_1_depth_161.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p004\04_1_depth_161.bmp 5.741192895847689
# E:\MestradoData\p004\04_1_depth_171.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p004\04_1_depth_171.bmp 5.678192846859929
# 86.87327417420329
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p004_10.csv
# E:\MestradoData\p004\04_10_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p004\04_10_depth_1.bmp 5.595873504495103
# E:\MestradoData\p004\04_10_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p004\04_10_depth_11.bmp 5.6793029694395045
# E:\MestradoData\p004\04_10_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p004\04_10_depth_21.bmp 5.831304429586453
# E:\MestradoData\p004\04_10_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p004\04_10_depth_41.bmp 5.644015688678792
# E:\MestradoData\p004\04_10_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p004\04_10_depth_51.bmp 6.074520039885556
# E:\MestradoData\p004\04_10_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p004\04_10_depth_61.bmp 5.931764597124129
# E:\MestradoData\p004\04_10_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p004\04_10_depth_71.bmp 5.651504867946642
# E:\MestradoData\p004\04_10_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p004\04_10_depth_81.bmp 5.994538275920149
# E:\MestradoData\p004\04_10_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p004\04_10_depth_91.bmp 5.617530376272498
# E:\MestradoData\p004\04_10_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p004\04_10_depth_101.bmp 5.526236818775942
# E:\MestradoData\p004\04_10_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p004\04_10_depth_111.bmp 5.50917411620776
# E:\MestradoData\p004\04_10_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p004\04_10_depth_121.bmp 5.689017134603546
# E:\MestradoData\p004\04_10_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p004\04_10_depth_131.bmp 5.543161644909105
# E:\MestradoData\p004\04_10_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p004\04_10_depth_141.bmp 5.6083803588103365
# E:\MestradoData\p004\04_10_depth_151.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p004\04_10_depth_151.bmp 5.691302959958193
# 85.5920560260297
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p004_11.csv
# E:\MestradoData\p004\04_11_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p004\04_11_depth_1.bmp 5.56288824660669
# E:\MestradoData\p004\04_11_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p004\04_11_depth_11.bmp 5.778685014372513
# E:\MestradoData\p004\04_11_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p004\04_11_depth_21.bmp 5.62043131225164
# E:\MestradoData\p004\04_11_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p004\04_11_depth_31.bmp 5.885842263038285
# E:\MestradoData\p004\04_11_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p004\04_11_depth_41.bmp 5.713178300698473
# E:\MestradoData\p004\04_11_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p004\04_11_depth_51.bmp 5.575832433910364
# E:\MestradoData\p004\04_11_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p004\04_11_depth_61.bmp 5.633729079522709
# E:\MestradoData\p004\04_11_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p004\04_11_depth_71.bmp 5.545862679812217
# E:\MestradoData\p004\04_11_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p004\04_11_depth_81.bmp 5.5397862401687235
# E:\MestradoData\p004\04_11_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p004\04_11_depth_91.bmp 5.618799313540876
# E:\MestradoData\p004\04_11_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p004\04_11_depth_101.bmp 5.517822405670813
# E:\MestradoData\p004\04_11_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p004\04_11_depth_111.bmp 5.545599568908983
# E:\MestradoData\p004\04_11_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p004\04_11_depth_121.bmp 5.555832844774159
# E:\MestradoData\p004\04_11_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p004\04_11_depth_131.bmp 5.566009626856612
# E:\MestradoData\p004\04_11_depth_141.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 15 E:\MestradoData\p004\04_11_depth_141.bmp 5.477303326575111
# 84.14201707297434
# 106
# (15, 22) C:\Users\rafae\Desktop\Coleta\faces\training_p004_12.csv
# E:\MestradoData\p004\04_12_depth_1.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 1 E:\MestradoData\p004\04_12_depth_1.bmp 5.7124336099286666
# E:\MestradoData\p004\04_12_depth_11.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 2 E:\MestradoData\p004\04_12_depth_11.bmp 5.545397297463751
# E:\MestradoData\p004\04_12_depth_21.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 3 E:\MestradoData\p004\04_12_depth_21.bmp 5.667455077566501
# E:\MestradoData\p004\04_12_depth_31.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 4 E:\MestradoData\p004\04_12_depth_31.bmp 5.636742608005989
# E:\MestradoData\p004\04_12_depth_41.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 5 E:\MestradoData\p004\04_12_depth_41.bmp 5.5148092722497495
# E:\MestradoData\p004\04_12_depth_51.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 6 E:\MestradoData\p004\04_12_depth_51.bmp 5.711132277624074
# E:\MestradoData\p004\04_12_depth_61.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 7 E:\MestradoData\p004\04_12_depth_61.bmp 5.6023580425812725
# E:\MestradoData\p004\04_12_depth_71.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 8 E:\MestradoData\p004\04_12_depth_71.bmp 5.6215394595246835
# E:\MestradoData\p004\04_12_depth_81.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 9 E:\MestradoData\p004\04_12_depth_81.bmp 5.822863942428739
# E:\MestradoData\p004\04_12_depth_91.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 10 E:\MestradoData\p004\04_12_depth_91.bmp 5.750848986983328
# E:\MestradoData\p004\04_12_depth_101.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 11 E:\MestradoData\p004\04_12_depth_101.bmp 5.9642678800846625
# E:\MestradoData\p004\04_12_depth_111.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 12 E:\MestradoData\p004\04_12_depth_111.bmp 5.577150753856131
# E:\MestradoData\p004\04_12_depth_121.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 13 E:\MestradoData\p004\04_12_depth_121.bmp 5.913904265556994
# E:\MestradoData\p004\04_12_depth_131.yaml
# (26,)
# (26,)
# (26,)
# (26,)
# (15, 22) 14 E:\MestradoData\p004\04_12_depth_131.bmp 5.7934618915855935
# E:\MestradoData\p004\04_12_depth_141.yaml

# %%
from sklearn.metrics import make_scorer,precision_recall_fscore_support


make_scorer(precision_recall_fscore_support, labels = [1,2,3])

# %%
ds.head()
